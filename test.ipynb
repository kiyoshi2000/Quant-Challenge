# %%
import yfinance as yf
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
from pso import *

# %%
tickers = ['NVDA', 'BRK-B', 'C', 'JPM']
start_date = '2020-01-01'
end_date = '2024-04-30'
population_size = 50
investment_amount = 100000

# Baixar os dados
data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
# data.index = pd.to_datetime(data.index)
# data[data.index > '2024-04-16 00:00:00+00:00']

rebalance_dates = pd.date_range(start=start_date, end=end_date, freq='3M')

for date in rebalance_dates:
    # Usar apenas dados anteriores à data de rebalanceamento
    historical_data = data[data.index <= date]
# Out:
# /var/folders/qk/g2d67vns3fq15rbqpxmhdrqm0000gn/T/ipykernel_74649/2940674599.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   rebalance_dates = pd.date_range(start=start_date, end=end_date, freq='3M')

# %%
data.index = data.index.tz_localize(None)

# %%
data.index[0]
# Out:
# Timestamp('2020-01-02 00:00:00')

# %%
rebalance_dates
# Out:
# DatetimeIndex(['2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31',
#                '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31',
#                '2022-01-31', '2022-04-30', '2022-07-31', '2022-10-31',
#                '2023-01-31', '2023-04-30', '2023-07-31', '2023-10-31',
#                '2024-01-31', '2024-04-30'],
#               dtype='datetime64[ns]', freq='3ME')
